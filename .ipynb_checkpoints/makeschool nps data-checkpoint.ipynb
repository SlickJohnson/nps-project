# %%
import pandas as pd
import numpy as np
import glob
import re
import seaborn as sns

# %matplotlib inline

# %%
df = pd.DataFrame(columns=["Location", "Week", "Rating", "Pacing", "Track"])

# %% [markdown]
# # Clean 2016 Data

# %% [markdown]
# The data for 2016 is in multiple files.

# %%
# Create empty DataFrame to dump data from csv files.
df_2016 = pd.DataFrame()

# Regex grabs weeks 1 - 7 and location from file name.
p = re.compile("Anon (Week \d) Feedback - (\w+).csv")
for csv in glob.glob("datasets/2016/*.csv"):
    match = p.search(csv)
    if match:
        csv_df = pd.read_csv(csv)
        csv_df['Week'] = match.group(1)[-1]
        csv_df['Location'] = match.group(2)
        df_2016 = df_2016.append(csv_df, ignore_index=True, sort=False)
pd.options.display.max_rows = 991
df_2016.head()
# Out:
#           Timestamp  \
# 0  8/5/2016 1:39:41
# 1  8/5/2016 1:40:47
# 2  8/5/2016 1:40:50
# 3  8/5/2016 1:42:44
# 4  8/5/2016 1:45:13
#
#   How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#   How well is the schedule paced? Week Location  \
# 0                               3    7   Taipei
# 1                               3    7   Taipei
# 2                               3    7   Taipei
# 3                               4    7   Taipei
# 4                               4    7   Taipei
#
#    How well are the tutorials paced? What track are you in? Unnamed: 0
# 0                                NaN                    NaN        NaN
# 1                                NaN                    NaN        NaN
# 2                                NaN                    NaN        NaN
# 3                                NaN                    NaN        NaN
# 4                                NaN                    NaN        NaN

# %%
# Only select the columns I'm interested in 
df_2016 = df_2016.iloc[:, [1, 2, 3, 4, 5, 6]]
# df_2016.head()
df_2016.rename(columns={
    "How would you rate your overall satisfaction with the Summer Academy this week?": "Rating",
    "How well is the schedule paced?": "Pacing",
    "How well are the tutorials paced?": "Pacing",
    "What track are you in?": "Track"
}, inplace=True)

# Combine columns with similar names.
def sjoin(x):
    return ';'.join(x[x.notnull()].astype(str))
df_2016 = df_2016.groupby(level=0, axis=1).apply(lambda x: x.apply(sjoin, axis=1))
df_2016
# Out:
#       Location Pacing Rating     Track Week
# 0       Taipei    3.0      3              7
# 1       Taipei    3.0      4              7
# 2       Taipei    3.0      4              7
# 3       Taipei    4.0      4              7
# 4       Taipei    4.0      5              7
# 5       Taipei    3.0      4              7
# 6       Taipei    3.0      4              7
# 7       Taipei    3.0      5              7
# 8       Taipei    3.0      5              7
# 9       Taipei    3.0      5              7
# 10      Taipei    3.0      3              7
# 11       Tokyo    4.0      3              6
# 12       Tokyo    3.0      4              6
# 13       Tokyo    1.0      4              6
# 14       Tokyo    2.0      4              6
# 15       Tokyo    4.0      5              6
# 16       Tokyo    3.0      3              6
# 17       Tokyo    5.0      5              6
# 18       Tokyo    2.0      4              6
# 19       Tokyo    4.0      3              6
# 20       Tokyo    3.0      5              6
# 21       Tokyo    3.0      5              6
# 22       Tokyo    4.0      4              6
# 23       Tokyo    3.0      4              6
# 24   Singapore    3.0      2              1
# 25   Singapore    3.0      2              1
# 26   Singapore    3.0      3              1
# 27   Singapore    4.0      4              1
# 28   Singapore    4.0      4              1
# 29   Singapore    4.0      4              1
# 30   Singapore    3.0      4              1
# 31   Singapore    3.0      4              1
# 32   Singapore    4.0      4              1
# 33   Singapore    3.0      4              1
# 34   Singapore    3.0      4              1
# 35   Singapore    5.0      5              1
# 36          LA    2.0      3     Intro    7
# 37          LA    3.0      5     Intro    7
# 38          LA    2.0      4     Games    7
# 39          LA    3.0      4     Intro    7
# 40          LA    3.0      4     Games    7
# 41          LA    3.0      5     Games    7
# 42          LA    4.0      4     Intro    7
# 43          LA    3.0      5     Games    7
# 44          LA    3.0      5     Games    7
# 45          SF    3.0      5      Apps    4
# 46          SF    3.0      4      Apps    4
# 47          SF    4.0      4      Apps    4
# 48          SF    4.0      3      Apps    4
# 49          SF    4.0      4      Apps    4
# 50          SF    4.0      3      Apps    4
# 51          SF    3.0      4      Apps    4
# 52          SF    3.0      5      Apps    4
# 53          SF    3.0      4      Apps    4
# 54          SF    3.0      4      Apps    4
# 55          SF    2.0      5      Apps    4
# 56          SF    3.0      4     Games    4
# 57          SF    3.0      4     Games    4
# 58          SF    4.0      5     Games    4
# 59          SF    5.0      5     Games    4
# 60          SF    3.0      5     Games    4
# 61          SF    4.0      5     Intro    4
# 62          SF    4.0      3     Intro    4
# 63          SF    4.0      4     Intro    4
# 64          SF    5.0      3     Intro    4
# 65          SF    4.0      4     Intro    4
# 66          SF    3.0      4     Intro    4
# 67          SF    3.0      3     Intro    4
# 68          SF    3.0      4     Intro    4
# 69          SF    3.0      5     Intro    4
# 70          SF    4.0      4     Intro    4
# 71          SF    3.0      5     Intro    4
# 72          SF    3.0      5        VR    4
# 73          SF    3.0      4        VR    4
# 74          SF    4.0      3        VR    4
# 75          SF    4.0      3        VR    4
# 76          SV    3.0      4      Apps    5
# 77          SV    3.0      5      Apps    5
# 78          SV    3.0      3      Apps    5
# 79          SV    3.0      2      Apps    5
# 80          SV    3.0      4     Games    5
# 81          SV    3.0      4     Games    5
# 82          SV    3.0      5      Apps    5
# 83          SV    3.0      3      Apps    5
# 84          SV    3.0      5      Apps    5
# 85          SV    4.0      4      Apps    5
# 86          SV    3.0      4      Apps    5
# 87          SV    3.0      5      Apps    5
# 88          SV    4.0      4     Intro    5
# 89          SV    3.0      5      Apps    5
# 90          SV    5.0      4      Apps    5
# 91          SV    2.0      2      Apps    5
# 92          SV    3.0      4      Apps    5
# 93          SV    4.0      5      Apps    5
# 94          SV    4.0      3      Apps    5
# 95          SV    4.0      4      Apps    5
# 96          SV    3.0      4      Apps    5
# 97          SV    3.0      4      Apps    5
# 98          SV    4.0      3      Apps    5
# 99          SV    3.0      5     Games    5
# 100         SV    3.0      5     Games    5
# 101         SV    5.0      4     Games    5
# 102         SV    3.0      4     Games    5
# 103         SV    3.0      4     Intro    5
# 104         SV    3.0      4     Intro    5
# 105         SV    3.0      5     Intro    5
# 106         SV    3.0      4     Intro    5
# 107         SV    3.0      4     Intro    5
# 108         SV    3.0      5     Intro    5
# 109         SV    4.0      4     Intro    5
# 110         SV    2.0      4     Intro    5
# 111         SV    3.0      5     Intro    5
# 112         SV    5.0      3     Games    5
# 113         SV    2.0      5     Games    5
# 114         SV    3.0      3     Games    5
# 115         SV    3.0      5     Games    5
# 116         SV    3.0      5     Games    5
# 117         SG    3.0      4              4
# 118         SG    4.0      4              4
# 119         SG    3.0      3              4
# 120         SG    3.0      4              4
# 121         SG    4.0      3              4
# 122         SG    3.0      4              4
# 123         SG    3.0      4              4
# 124         SG    4.0      3              4
# 125         SG    3.0      4              4
# 126         NY    2.0      2      Apps    6
# 127         NY    3.0      4      Apps    6
# 128         NY    4.0      4      Apps    6
# 129         NY    3.0      5      Apps    6
# 130         NY    3.0      5     Games    6
# 131         NY    3.0      4     Intro    6
# 132         NY    3.0      3      Apps    6
# 133         NY    3.0      5      Apps    6
# 134         NY    3.0      3     Games    6
# 135         NY    3.0      4      Apps    6
# 136         NY    4.0      5     Intro    6
# 137         NY    3.0      4     Intro    6
# 138         NY    3.0      5      Apps    6
# 139         NY    1.0      2      Apps    6
# 140         NY    3.0      4     Intro    6
# 141         NY    3.0      4      Apps    6
# 142         NY    3.0      5     Intro    6
# 143         NY    3.0      4     Games    6
# 144         NY    5.0      5      Apps    6
# 145         NY    3.0      4     Games    6
# 146         HK    3.0      4              5
# 147         HK    3.0      5              5
# 148         HK    3.0      5              5
# 149         SF    2.0      3      Apps    1
# 150         SF    3.0      3      Apps    1
# 151         SF    4.0      3      Apps    1
# 152         SF    5.0      3      Apps    1
# 153         SF    2.0      4      Apps    1
# 154         SF    2.0      4      Apps    1
# 155         SF    2.0      4      Apps    1
# 156         SF    3.0      4      Apps    1
# 157         SF    3.0      4      Apps    1
# 158         SF    3.0      4      Apps    1
# 159         SF    3.0      4      Apps    1
# 160         SF    3.0      4      Apps    1
# 161         SF    3.0      4      Apps    1
# 162         SF    3.0      4      Apps    1
# 163         SF    3.0      4      Apps    1
# 164         SF    3.0      4      Apps    1
# 165         SF    3.0      4      Apps    1
# 166         SF    3.0      4      Apps    1
# 167         SF    3.0      4      Apps    1
# 168         SF    3.0      4      Apps    1
# 169         SF    3.0      4      Apps    1
# 170         SF    4.0      4      Apps    1
# 171         SF    4.0      4      Apps    1
# 172         SF    4.0      4      Apps    1
# 173         SF    4.0      4      Apps    1
# 174         SF    4.0      4      Apps    1
# 175         SF    5.0      4      Apps    1
# 176         SF    5.0      4      Apps    1
# 177         SF    2.0      4      Apps    1
# 178         SF    2.0      5      Apps    1
# 179         SF    2.0      5      Apps    1
# 180         SF    3.0      5      Apps    1
# 181         SF    3.0      5      Apps    1
# 182         SF    3.0      5      Apps    1
# 183         SF    3.0      5      Apps    1
# 184         SF    3.0      5      Apps    1
# 185         SF    3.0      5      Apps    1
# 186         SF    3.0      5      Apps    1
# 187         SF    3.0      5      Apps    1
# 188         SF    3.0      5      Apps    1
# 189         SF    3.0      5      Apps    1
# 190         SF    3.0      5      Apps    1
# 191         SF    3.0      5      Apps    1
# 192         SF    3.0      5      Apps    1
# 193         SF    3.0      5      Apps    1
# 194         SF    3.0      5      Apps    1
# 195         SF    3.0      5      Apps    1
# 196         SF    3.0      5      Apps    1
# 197         SF    4.0      5      Apps    1
# 198         SF    4.0      5      Apps    1
# 199         SF    4.0      5      Apps    1
# 200         SF    4.0      5      Apps    1
# 201         SF    4.0      5      Apps    1
# 202         SF    4.0      5      Apps    1
# 203         SF    4.0      5      Apps    1
# 204         SF    4.0      5      Apps    1
# 205         SF    3.0      5      Apps    1
# 206         SF    3.0      5      Apps    1
# 207         SF    3.0      4     Games    1
# 208         SF    3.0      4     Games    1
# 209         SF    4.0      4     Games    1
# 210         SF    3.0      5     Games    1
# 211         SF    3.0      5     Games    1
# 212         SF    3.0      5     Games    1
# 213         SF    3.0      5     Games    1
# 214         SF    3.0      5     Games    1
# 215         SF    4.0      5     Games    1
# 216         SF    4.0      5     Games    1
# 217         SF    3.0      3     Intro    1
# 218         SF    3.0      4     Intro    1
# 219         SF    3.0      4     Intro    1
# 220         SF    3.0      4     Intro    1
# 221         SF    3.0      4     Intro    1
# 222         SF    3.0      4     Intro    1
# 223         SF    3.0      4     Intro    1
# 224         SF    4.0      4     Intro    1
# 225         SF    4.0      4     Intro    1
# 226         SF    4.0      4     Intro    1
# 227         SF    2.0      5     Intro    1
# 228         SF    3.0      5     Intro    1
# 229         SF    3.0      5     Intro    1
# 230         SF    3.0      5     Intro    1
# 231         SF    3.0      5     Intro    1
# 232         SF    3.0      5     Intro    1
# 233         SF    4.0      5     Intro    1
# 234         SF    4.0      5     Intro    1
# 235         SF    5.0      5     Intro    1
# 236         SF    5.0      5     Intro    1
# 237         SF    3.0      5     Intro    1
# 238         SF    3.0      3        VR    1
# 239         SF    3.0      5        VR    1
# 240         SF    3.0      5        VR    1
# 241         SF    3.0      5        VR    1
# 242         LA    2.0      4              2
# 243         LA    3.0      3              2
# 244         LA    4.0      4              2
# 245         LA    3.0      4              2
# 246         LA    3.0      4              2
# 247         LA    3.0      5              2
# 248         LA    3.0      5              2
# 249     Taipei    3.0      5              6
# 250     Taipei    4.0      5              6
# 251     Taipei    3.0      5              6
# 252     Taipei    3.0      5              6
# 253     Taipei    3.0      4              6
# 254     Taipei    3.0      4              6
# 255     Taipei    4.0      3              6
# 256     Taipei    3.0      3              6
# 257     Taipei    2.0      5              6
# 258     Taipei    4.0      4              6
# 259     Taipei    4.0      5              6
# 260     Taipei    3.0      5              6
# 261         NY    3.0      4      Apps    3
# 262         NY    3.0      5      Apps    3
# 263         NY    3.0      4     Intro    3
# 264         NY    3.0      5      Apps    3
# 265         NY    2.0      4      Apps    3
# 266         NY    4.0      4     Games    3
# 267         NY    4.0      4     Intro    3
# 268         NY    3.0      5      Apps    3
# 269         NY    4.0      4     Games    3
# 270         NY    4.0      4     Intro    3
# 271         NY    4.0      4     Games    3
# 272         NY    4.0      4      Apps    3
# 273         NY    3.0      4      Apps    3
# 274         NY    3.0      4     Games    3
# 275         NY    4.0      5      Apps    3
# 276         NY    3.0      4      Apps    3
# 277         NY    4.0      4     Games    3
# 278         NY    4.0      5     Games    3
# 279         NY    4.0      4     Intro    3
# 280         NY    4.0      4      Apps    3
# 281         NY    3.0      5     Games    3
# 282         NY    4.0      3     Intro    3
# 283         NY    3.0      5      Apps    3
# 284         NY    3.0      5      Apps    3
# 285         NY    4.0      4     Intro    3
# 286         NY    3.0      5     Games    3
# 287         NY    3.0      5     Games    3
# 288         NY    3.0      4      Apps    3
# 289         LA    3.0      5     Games    6
# 290         LA    3.0      5     Intro    6
# 291         LA    1.0      3     Games    6
# 292         LA    3.0      1     Games    6
# 293         LA    3.0      5     Intro    6
# 294         LA    3.0      5     Intro    6
# 295         LA    3.0      5     Games    6
# 296         LA    3.0      4     Games    6
# 297         LA    4.0      4     Intro    6
# 298         LA    4.0      4     Games    6
# 299         SF    3.0      3      Apps    5
# 300         SF    3.0      4      Apps    5
# 301         SF    3.0      4      Apps    5
# 302         SF    4.0      4      Apps    5
# 303         SF    3.0      3      Apps    5
# 304         SF    3.0      5      Apps    5
# 305         SF    2.0      3      Apps    5
# 306         SF    3.0      5      Apps    5
# 307         SF    3.0      1      Apps    5
# 308         SF    3.0      4      Apps    5
# 309         SF    3.0      5      Apps    5
# 310         SF    4.0      4      Apps    5
# 311         SF    4.0      3      Apps    5
# 312         SF    3.0      4     Games    5
# 313         SF    3.0      5     Games    5
# 314         SF    5.0      1     Games    5
# 315         SF    3.0      5     Games    5
# 316         SF    3.0      4     Games    5
# 317         SF    3.0      5     Games    5
# 318         SF    2.0      5     Intro    5
# 319         SF    3.0      4     Intro    5
# 320         SF    5.0      3     Intro    5
# 321         SF    3.0      5     Intro    5
# 322         SF    4.0      5     Intro    5
# 323         SF    3.0      5     Intro    5
# 324         SF    3.0      5     Intro    5
# 325         SF    3.0      5     Intro    5
# 326         SF    2.0      5     Intro    5
# 327         SF    3.0      5     Intro    5
# 328         SF    3.0      5     Intro    5
# 329         SF    3.0      4     Intro    5
# 330         SF    3.0      5     Intro    5
# 331         SF    3.0      5     Intro    5
# 332         SF    4.0      4     Intro    5
# 333         SF    3.0      5     Intro    5
# 334         SF    3.0      5     Intro    5
# 335         SF    4.0      5        VR    5
# 336         SF    4.0      5        VR    5
# 337         SF    4.0      4        VR    5
# 338         SF    3.0      5        VR    5
# 339         SF    3.0      3     Intro    5
# 340         SF    3.0      3     Intro    5
# 341         SG    3.0      4              5
# 342         SG    3.0      4              5
# 343         SG    4.0      4              5
# 344         SG    3.0      4              5
# 345         SG    4.0      4              5
# 346         SG    3.0      4              5
# 347         SG    3.0      4              5
# 348         SG    3.0      3              5
# 349         SG    3.0      4              5
# 350         SG    3.0      4              5
# 351         SG    2.0      2              5
# 352         SV    1.0      2      Apps    4
# 353         SV    3.0      3      Apps    4
# 354         SV    4.0      4      Apps    4
# 355         SV    3.0      4      Apps    4
# 356         SV    3.0      5      Apps    4
# 357         SV    3.0      4      Apps    4
# 358         SV    3.0      4      Apps    4
# 359         SV    3.0      4      Apps    4
# 360         SV    2.0      4      Apps    4
# 361         SV    4.0      4      Apps    4
# 362         SV    3.0      3      Apps    4
# 363         SV    4.0      4      Apps    4
# 364         SV    3.0      5      Apps    4
# 365         SV    3.0      4      Apps    4
# 366         SV    3.0      5      Apps    4
# 367         SV    4.0      3      Apps    4
# 368         SV    3.0      4      Apps    4
# 369         SV    4.0      4      Apps    4
# 370         SV    4.0      4      Apps    4
# 371         SV    4.0      4      Apps    4
# 372         SV    3.0      5      Apps    4
# 373         SV    4.0      5      Apps    4
# 374         SV    3.0      5      Apps    4
# 375         SV    4.0      4      Apps    4
# 376         SV    1.0      5      Apps    4
# 377         SV    3.0      5      Apps    4
# 378         SV    3.0      4      Apps    4
# 379         SV    2.0      5     Games    4
# 380         SV    3.0      5     Games    4
# 381         SV    3.0      4     Games    4
# 382         SV    4.0      4     Games    4
# 383         SV    4.0      4     Games    4
# 384         SV    5.0      5     Games    4
# 385         SV    3.0      5     Games    4
# 386         SV    3.0      3     Games    4
# 387         SV    4.0      5     Intro    4
# 388         NY    3.0      3      Apps    7
# 389         NY    3.0      5      Apps    7
# 390         NY    3.0      5     Games    7
# 391         NY    3.0      4     Games    7
# 392         NY    3.0      4      Apps    7
# 393         NY    4.0      4     Intro    7
# 394         NY    3.0      5      Apps    7
# 395         NY    4.0      5     Games    7
# 396         NY    3.0      4     Games    7
# 397         NY    3.0      4      Apps    7
# 398         NY    3.0      5     Intro    7
# 399         NY    3.0      3     Games    7
# 400         NY    4.0      5     Games    7
# 401         NY    3.0      4      Apps    7
# 402         NY    3.0      4     Intro    7
# 403         NY    3.0      4      Apps    7
# 404         NY    4.0      5     Intro    7
# 405         LA    2.0      4              3
# 406         LA    4.0      4              3
# 407         LA    3.0      4              3
# 408         LA    3.0      4              3
# 409         LA    3.0      4              3
# 410         LA    4.0      5              3
# 411         NY    2.0      3      Apps    2
# 412         NY    4.0      3      Apps    2
# 413         NY    5.0      3     Games    2
# 414         NY    3.0      3     Games    2
# 415         NY    3.0      4      Apps    2
# 416         NY    4.0      4      Apps    2
# 417         NY    3.0      4      Apps    2
# 418         NY    3.0      4      Apps    2
# 419         NY    2.0      4      Apps    2
# 420         NY    4.0      4      Apps    2
# 421         NY    3.0      4      Apps    2
# 422         NY    4.0      4     Games    2
# 423         NY    4.0      4     Games    2
# 424         NY    4.0      4     Games    2
# 425         NY    3.0      4     Intro    2
# 426         NY    3.0      4     Intro    2
# 427         NY    4.0      4     Intro    2
# 428         NY    3.0      4     Intro    2
# 429         NY    3.0      5      Apps    2
# 430         NY    3.0      5      Apps    2
# 431         NY    3.0      5      Apps    2
# 432         NY    4.0      5      Apps    2
# 433         NY    3.0      5      Apps    2
# 434         NY    4.0      5      Apps    2
# 435         NY    4.0      5     Games    2
# 436         NY    3.0      5     Intro    2
# 437         NY    3.0      5     Intro    2
# 438         NY    3.0      5     Intro    2
# 439         SV    4.0      2     Games    1
# 440         SV    4.0      3      Apps    1
# 441         SV    3.0      3      Apps    1
# 442         SV    5.0      3      Apps    1
# 443         SV    3.0      3      Apps    1
# 444         SV    3.0      3     Games    1
# 445         SV    4.0      4      Apps    1
# 446         SV    3.0      4      Apps    1
# 447         SV    3.0      4      Apps    1
# 448         SV    4.0      4      Apps    1
# 449         SV    3.0      4      Apps    1
# 450         SV    4.0      4      Apps    1
# 451         SV    4.0      4      Apps    1
# 452         SV    3.0      4      Apps    1
# 453         SV    4.0      4      Apps    1
# 454         SV    3.0      4      Apps    1
# 455         SV    4.0      4      Apps    1
# 456         SV    4.0      4      Apps    1
# 457         SV    3.0      4      Apps    1
# 458         SV    3.0      4      Apps    1
# 459         SV    5.0      4      Apps    1
# 460         SV    3.0      4      Apps    1
# 461         SV    3.0      4      Apps    1
# 462         SV    3.0      4      Apps    1
# 463         SV    4.0      4     Games    1
# 464         SV    4.0      4     Games    1
# 465         SV    4.0      4     Games    1
# 466         SV    3.0      4     Games    1
# 467         SV    4.0      4     Games    1
# 468         SV    3.0      4     Games    1
# 469         SV    4.0      4     Games    1
# 470         SV    3.0      4     Games    1
# 471         SV    4.0      4     Games    1
# 472         SV    4.0      4     Intro    1
# 473         SV    3.0      4     Intro    1
# 474         SV    4.0      4     Intro    1
# 475         SV    3.0      4     Intro    1
# 476         SV    4.0      4     Intro    1
# 477         SV    3.0      4     Intro    1
# 478         SV    3.0      4     Intro    1
# 479         SV    3.0      4     Intro    1
# 480         SV    3.0      5      Apps    1
# 481         SV    3.0      5      Apps    1
# 482         SV    3.0      5      Apps    1
# 483         SV    3.0      5      Apps    1
# 484         SV    3.0      5      Apps    1
# 485         SV    3.0      5      Apps    1
# 486         SV    4.0      5      Apps    1
# 487         SV    4.0      5      Apps    1
# 488         SV    3.0      5      Apps    1
# 489         SV    4.0      5      Apps    1
# 490         SV    4.0      5      Apps    1
# 491         SV    4.0      5     Games    1
# 492         SV    2.0      5     Games    1
# 493         SV    3.0      5     Games    1
# 494         SV    4.0      5     Games    1
# 495         SV    3.0      5     Intro    1
# 496         SV    2.0      5     Intro    1
# 497         SV    3.0      5     Intro    1
# 498         SV    3.0      5     Intro    1
# 499         SV    3.0      5     Intro    1
# 500         SV    3.0      5     Intro    1
# 501         LA    2.0      3     Games    5
# 502         LA    3.0      4     Intro    5
# 503         LA    3.0      5     Intro    5
# 504         LA    3.0      4     Games    5
# 505         LA    3.0      4     Intro    5
# 506         LA    3.0      4     Games    5
# 507         LA    3.0      5     Intro    5
# 508         LA    4.0      4     Games    5
# 509         LA    4.0      5     Games    5
# 510         LA    3.0      5     Intro    5
# 511         LA    3.0      4     Games    5
# 512         LA    3.0      4     Games    5
# 513         SF    3.0      4      Apps    6
# 514         SF    4.0      3      Apps    6
# 515         SF    3.0      2      Apps    6
# 516         SF    3.0      4      Apps    6
# 517         SF    4.0      3      Apps    6
# 518         SF    3.0      5      Apps    6
# 519         SF    3.0      1      Apps    6
# 520         SF    3.0      3      Apps    6
# 521         SF    3.0      5      Apps    6
# 522         SF    3.0      4      Apps    6
# 523         SF    3.0      5      Apps    6
# 524         SF    3.0      5     Games    6
# 525         SF    3.0      5     Games    6
# 526         SF    3.0      4     Games    6
# 527         SF    4.0      5     Games    6
# 528         SF    4.0      5     Games    6
# 529         SF    4.0      3     Games    6
# 530         SF    3.0      5     Intro    6
# 531         SF    3.0      5     Intro    6
# 532         SF    4.0      3     Intro    6
# 533         SF    3.0      5     Intro    6
# 534         SF    3.0      5     Intro    6
# 535         SF    3.0      4        VR    6
# 536         SF    4.0      4        VR    6
# 537         SF    3.0      4        VR    6
# 538         SG    3.0      4              6
# 539         SG    5.0      5              6
# 540         SG    3.0      5              6
# 541         SG    3.0      4              6
# 542         SG    5.0      3              6
# 543         SG    3.0      5              6
# 544         SV    3.0      3      Apps    7
# 545         SV    3.0      5      Apps    7
# 546         SV    3.0      3      Apps    7
# 547         SV    3.0      4      Apps    7
# 548         SV    3.0      4      Apps    7
# 549         SV    3.0      4      Apps    7
# 550         SV    3.0      3      Apps    7
# 551         SV    3.0      3      Apps    7
# 552         SV    3.0      5      Apps    7
# 553         SV    4.0      4      Apps    7
# 554         SV    3.0      4      Apps    7
# 555         SV    3.0      4      Apps    7
# 556         SV    3.0      4      Apps    7
# 557         SV    3.0      5      Apps    7
# 558         SV    3.0      4      Apps    7
# 559         SV    1.0      3      Apps    7
# 560         SV    2.0      5      Apps    7
# 561         SV    3.0      5      Apps    7
# 562         SV    3.0      3      Apps    7
# 563         SV    3.0      4      Apps    7
# 564         SV    3.0      2      Apps    7
# 565         SV    3.0      3      Apps    7
# 566         SV    4.0      3      Apps    7
# 567         SV    5.0      5      Apps    7
# 568         SV    4.0      5     Games    7
# 569         SV    3.0      3     Games    7
# 570         SV    3.0      5     Games    7
# 571         SV    4.0      5     Games    7
# 572         SV    5.0      5     Games    7
# 573         SV    3.0      4     Games    7
# 574         SV    3.0      4     Games    7
# 575         SV    3.0      5     Games    7
# 576         SV    4.0      4     Games    7
# 577         SV    3.0      5     Games    7
# 578         SV    3.0      3     Games    7
# 579         SV    4.0      4     Intro    7
# 580         SV    3.0      4     Intro    7
# 581         SV    3.0      5     Intro    7
# 582         SV    3.0      5     Intro    7
# 583         SV    3.0      5     Intro    7
# 584         SV    3.0      5     Intro    7
# 585         SV    4.0      5     Intro    7
# 586         SV    4.0      4     Intro    7
# 587         SV    3.0      4     Intro    7
# 588         SV    3.0      5     Intro    7
# 589         SV    2.0      4     Intro    7
# 590         SV    3.0      3      Apps    7
# 591         NY    3.0      5      Apps    4
# 592         NY    3.0      5      Apps    4
# 593         NY    3.0      4      Apps    4
# 594         NY    3.0      4      Apps    4
# 595         NY    4.0      4     Games    4
# 596         NY    4.0      4     Intro    4
# 597         NY    4.0      4      Apps    4
# 598         NY    3.0      5      Apps    4
# 599         NY    5.0      4      Apps    4
# 600         NY    3.0      5      Apps    4
# 601         NY    4.0      4      Apps    4
# 602         NY    4.0      4     Games    4
# 603         NY    3.0      5      Apps    4
# 604         NY    3.0      4     Games    4
# 605         NY    3.0      4      Apps    4
# 606         NY    3.0      4      Apps    4
# 607         SF    2.0      3      Apps    3
# 608         SF    3.0      5      Apps    3
# 609         SF    3.0      3      Apps    3
# 610         SF    3.0      1      Apps    3
# 611         SF    2.0      5      Apps    3
# 612         SF    5.0      5      Apps    3
# 613         SF    5.0      3      Apps    3
# 614         SF    3.0      5      Apps    3
# 615         SF    3.0      5      Apps    3
# 616         SF    3.0      5     Games    3
# 617         SF    4.0      5     Games    3
# 618         SF    3.0      5     Intro    3
# 619         SF    3.0      4     Intro    3
# 620         SF    3.0      4     Intro    3
# 621         SF    4.0      4     Intro    3
# 622         SF    3.0      5     Intro    3
# 623         SF    3.0      5     Intro    3
# 624         SF    3.0      5        VR    3
# 625         SF    4.0      4        VR    3
# 626         SF    5.0      1        VR    3
# 627         SF    4.0      4        VR    3
# 628         SF    4.0      3     Intro    3
# 629         SF    4.0      4     Intro    3
# 630         NY    5.0      3     Games    1
# 631         NY    3.0      3     Games    1
# 632         NY    3.0      3      Apps    1
# 633         NY    3.0      4     Intro    1
# 634         NY    4.0      4     Intro    1
# 635         NY    4.0      4     Intro    1
# 636         NY    4.0      4     Intro    1
# 637         NY    4.0      4     Games    1
# 638         NY    4.0      4     Games    1
# 639         NY    3.0      4     Games    1
# 640         NY    3.0      4     Games    1
# 641         NY    4.0      4     Games    1
# 642         NY    4.0      4      Apps    1
# 643         NY    4.0      4      Apps    1
# 644         NY    4.0      4      Apps    1
# 645         NY    3.0      4      Apps    1
# 646         NY    4.0      4      Apps    1
# 647         NY    2.0      4      Apps    1
# 648         NY    3.0      4      Apps    1
# 649         NY    4.0      4      Apps    1
# 650         NY    4.0      4      Apps    1
# 651         NY    3.0      4      Apps    1
# 652         NY    3.0      5     Intro    1
# 653         NY    3.0      5     Intro    1
# 654         NY    4.0      5     Intro    1
# 655         NY    4.0      5     Intro    1
# 656         NY    3.0      5     Games    1
# 657         NY    3.0      5     Games    1
# 658         NY    4.0      5     Games    1
# 659         NY    3.0      5      Apps    1
# 660         NY    4.0      5      Apps    1
# 661         NY    3.0      5      Apps    1
# 662         NY    3.0      5      Apps    1
# 663         NY    4.0      5      Apps    1
# 664         NY    4.0      5      Apps    1
# 665         NY    3.0      5      Apps    1
# 666         NY    3.0      5      Apps    1
# 667         NY    4.0      5      Apps    1
# 668         NY    3.0      5      Apps    1
# 669         SV    4.0      3      Apps    2
# 670         SV    5.0      3      Apps    2
# 671         SV    3.0      3      Apps    2
# 672         SV    4.0      3      Apps    2
# 673         SV    3.0      3      Apps    2
# 674         SV    3.0      3      Apps    2
# 675         SV    3.0      3      Apps    2
# 676         SV    4.0      3      Apps    2
# 677         SV    3.0      3      Apps    2
# 678         SV    3.0      3     Games    2
# 679         SV    5.0      3     Games    2
# 680         SV    3.0      3     Games    2
# 681         SV    3.0      3     Games    2
# 682         SV    4.0      3     Intro    2
# 683         SV    3.0      4      Apps    2
# 684         SV    3.0      4      Apps    2
# 685         SV    3.0      4      Apps    2
# 686         SV    4.0      4      Apps    2
# 687         SV    4.0      4      Apps    2
# 688         SV    3.0      4      Apps    2
# 689         SV    4.0      4      Apps    2
# 690         SV    3.0      4      Apps    2
# 691         SV    4.0      4      Apps    2
# 692         SV    3.0      4      Apps    2
# 693         SV    3.0      4      Apps    2
# 694         SV    3.0      4      Apps    2
# 695         SV    3.0      4      Apps    2
# 696         SV    4.0      4      Apps    2
# 697         SV    4.0      4      Apps    2
# 698         SV    4.0      4      Apps    2
# 699         SV    4.0      4     Games    2
# 700         SV    2.0      4     Games    2
# 701         SV    3.0      4     Games    2
# 702         SV    2.0      4     Games    2
# 703         SV    3.0      4     Games    2
# 704         SV    3.0      4     Intro    2
# 705         SV    3.0      4     Intro    2
# 706         SV    3.0      4     Intro    2
# 707         SV    4.0      4     Intro    2
# 708         SV    4.0      4     Intro    2
# 709         SV    3.0      4     Intro    2
# 710         SV    3.0      4     Intro    2
# 711         SV    3.0      5      Apps    2
# 712         SV    3.0      5      Apps    2
# 713         SV    4.0      5      Apps    2
# 714         SV    3.0      5      Apps    2
# 715         SV    4.0      5      Apps    2
# 716         SV    3.0      5      Apps    2
# 717         SV    3.0      5      Apps    2
# 718         SV    4.0      5     Games    2
# 719         SV    2.0      5     Games    2
# 720         SV    3.0      5     Games    2
# 721         SV    4.0      5     Games    2
# 722         SV    2.0      5     Intro    2
# 723         SV    5.0      5     Intro    2
# 724         SV    2.0      5     Intro    2
# 725         SG    3.0      4              3
# 726         SG    3.0      5              3
# 727         LA    3.0      5              4
# 728         LA    3.0      5              4
# 729         LA    3.0      5              4
# 730         LA    4.0      5              4
# 731         LA    3.0      3              4
# 732         LA    3.0      4              4
# 733         LA    3.0      4              4
# 734         LA    3.0      4              4
# 735         SF    5.0      5      Apps    7
# 736         SF    3.0      3      Apps    7
# 737         SF    3.0      5      Apps    7
# 738         SF    4.0      5      Apps    7
# 739         SF    3.0      4      Apps    7
# 740         SF    3.0      5      Apps    7
# 741         SF    3.0      5      Apps    7
# 742         SF    4.0      4      Apps    7
# 743         SF    3.0      5     Games    7
# 744         SF    4.0      5     Games    7
# 745         SF    3.0      4     Intro    7
# 746         SF    4.0      4     Intro    7
# 747         SF    3.0      5     Intro    7
# 748         SF    3.0      5     Intro    7
# 749         SF    5.0      4     Intro    7
# 750         SF    3.0      5        VR    7
# 751         SF    3.0      1        VR    7
# 752         SF    5.0      3        VR    7
# 753         SF    2.0      2        VR    7
# 754         SV    3.0      4      Apps    6
# 755         SV    3.0      5      Apps    6
# 756         SV    4.0      5      Apps    6
# 757         SV    3.0      4      Apps    6
# 758         SV    3.0      3      Apps    6
# 759         SV    3.0      3      Apps    6
# 760         SV    3.0      4      Apps    6
# 761         SV    3.0      5      Apps    6
# 762         SV    2.0      2      Apps    6
# 763         SV    3.0      4      Apps    6
# 764         SV    3.0      3      Apps    6
# 765         SV    3.0      5      Apps    6
# 766         SV    2.0      5      Apps    6
# 767         SV    3.0      3     Games    6
# 768         SV    3.0      4     Games    6
# 769         SV    3.0      4     Games    6
# 770         SV    3.0      5     Games    6
# 771         SV    3.0      4     Games    6
# 772         SV    4.0      4     Games    6
# 773         SV    4.0      4     Games    6
# 774         SV    4.0      3     Games    6
# 775         SV    3.0      4     Games    6
# 776         SV    4.0      4     Games    6
# 777         SV    2.0      4     Games    6
# 778         SV    3.0      5     Intro    6
# 779         SV    2.0      5     Intro    6
# 780         SV    3.0      5     Intro    6
# 781         SV    4.0      5     Intro    6
# 782         SV    4.0      3     Intro    6
# 783         SV    3.0      4     Intro    6
# 784         SV    3.0      4     Intro    6
# 785         SV    3.0      4     Intro    6
# 786         SV    3.0      4     Intro    6
# 787         SV    3.0      5     Intro    6
# 788         SV    2.0      4     Intro    6
# 789         HK    3.0      5              6
# 790         HK    3.0      4              6
# 791         HK    3.0      5              6
# 792         NY    5.0      5      Apps    5
# 793         NY    3.0      5      Apps    5
# 794         NY    3.0      4      Apps    5
# 795         NY    3.0      4      Apps    5
# 796         NY    3.0      5      Apps    5
# 797         NY    4.0      4      Apps    5
# 798         NY    5.0      3     Games    5
# 799         NY    4.0      4      Apps    5
# 800         NY    4.0      5      Apps    5
# 801         NY    3.0      4     Games    5
# 802         NY    3.0      4      Apps    5
# 803         NY    4.0      4     Games    5
# 804         NY    3.0      4     Intro    5
# 805         NY    3.0      4      Apps    5
# 806         NY    3.0      5     Games    5
# 807         NY    3.0      4      Apps    5
# 808         NY    3.0      5     Games    5
# 809         NY    3.0      4      Apps    5
# 810         NY    3.0      5     Games    5
# 811         NY    3.0      5      Apps    5
# 812         NY    3.0      4     Games    5
# 813         SF    3.0      2      Apps    2
# 814         SF    2.0      3      Apps    2
# 815         SF    3.0      3      Apps    2
# 816         SF    3.0      3      Apps    2
# 817         SF    2.0      4      Apps    2
# 818         SF    2.0      4      Apps    2
# 819         SF    5.0      4      Apps    2
# 820         SF    3.0      4      Apps    2
# 821         SF    4.0      4      Apps    2
# 822         SF    4.0      4      Apps    2
# 823         SF    3.0      4      Apps    2
# 824         SF    5.0      4      Apps    2
# 825         SF    3.0      4      Apps    2
# 826         SF    3.0      4      Apps    2
# 827         SF    3.0      4      Apps    2
# 828         SF    2.0      4      Apps    2
# 829         SF    3.0      4      Apps    2
# 830         SF    3.0      5      Apps    2
# 831         SF    2.0      5      Apps    2
# 832         SF    3.0      5      Apps    2
# 833         SF    3.0      5      Apps    2
# 834         SF    4.0      5      Apps    2
# 835         SF    3.0      5      Apps    2
# 836         SF    3.0      5      Apps    2
# 837         SF    2.0      5      Apps    2
# 838         SF    3.0      5      Apps    2
# 839         SF    4.0      5      Apps    2
# 840         SF    3.0      5      Apps    2
# 841         SF    4.0      4     Games    2
# 842         SF    5.0      4     Games    2
# 843         SF    3.0      5     Games    2
# 844         SF    3.0      5     Games    2
# 845         SF    3.0      5     Games    2
# 846         SF    3.0      5     Games    2
# 847         SF    3.0      5     Games    2
# 848         SF    3.0      5     Games    2
# 849         SF    3.0      5     Games    2
# 850         SF    3.0      3     Intro    2
# 851         SF    2.0      4     Intro    2
# 852         SF    3.0      4     Intro    2
# 853         SF    3.0      4     Intro    2
# 854         SF    3.0      4     Intro    2
# 855         SF    4.0      4     Intro    2
# 856         SF    4.0      4     Intro    2
# 857         SF    4.0      4     Intro    2
# 858         SF    4.0      4     Intro    2
# 859         SF    3.0      4     Intro    2
# 860         SF    4.0      4     Intro    2
# 861         SF    3.0      4     Intro    2
# 862         SF    3.0      4     Intro    2
# 863         SF    4.0      5     Intro    2
# 864         SF    3.0      5     Intro    2
# 865         SF    3.0      5     Intro    2
# 866         SF    3.0      5     Intro    2
# 867         SF    3.0      5     Intro    2
# 868         SF    3.0      1        VR    2
# 869         SF    3.0      2        VR    2
# 870         SF    3.0      2        VR    2
# 871         SF    3.0      5        VR    2
# 872         SF    3.0      5        VR    2
# 873         SF    3.0      5        VR    2
# 874         SF    3.0      5        VR    2
# 875         LA    4.0      3              1
# 876         LA    4.0      4              1
# 877         LA    4.0      4              1
# 878         LA    4.0      4              1
# 879         LA    5.0      4              1
# 880         LA    4.0      5              1
# 881         LA    3.0      5              1
# 882         SG    3.0      4              2
# 883         SG    3.0      3              2
# 884         SG    5.0      3              2
# 885         SG    3.0      3              2
# 886         SG    4.0      4              2
# 887         SG    3.0      4              2
# 888         SG    3.0      3              2
# 889         SG    3.0      3              2
# 890         SV      2      5     Games    3
# 891         SV      3      5      Apps    3
# 892         SV      3      4     Games    3
# 893         SV      3      4      Apps    3
# 894         SV      4      4      Apps    3
# 895         SV      3      5      Apps    3
# 896         SV      4      4      Apps    3
# 897         SV      4      3      Apps    3
# 898         SV      4      4      Apps    3
# 899         SV      4      3      Apps    3
# 900         SV      2      3      Apps    3
# 901         SV      4      5      Apps    3
# 902         SV      5      5     Games    3
# 903         SV      3      4     Games    3
# 904         SV      3      5     Games    3
# 905         SV      3      5     Intro    3
# 906         SV      3      4      Apps    3
# 907         SV      3      5     Games    3
# 908         SV      3      5     Games    3
# 909         SV      2      5     Games    3
# 910         SV      3      3      Apps    3
# 911         SV      3      3     Games    3
# 912         SV      3      4      Apps    3
# 913         SV      2      4      Apps    3
# 914         SV      5      4     Games    3
# 915         SV      4      4     Intro    3
# 916         SV      4      4     Intro    3
# 917         SV      3      4     Intro    3
# 918         SV      3      4     Intro    3
# 919         SV      3      4     Intro    3
# 920         SV      3      4     Intro    3
# 921         SV      4      4     Intro    3
# 922         SV      4      4     Games    3
# 923         SV  #REF!  #REF!  Average:    3
# 924         SV      3      5      Apps    3
# 925         SV      3      5     Games    3
# 926         SV      3      5     Intro    3

# %% [markdown]
# One more thing! There's a row with unusable data. That will be curbed!

# %%
df_2016.drop(923, inplace=True)

# %% [markdown]
# Now the dataset is reletavily clean and ready to be combined with week 8's data.
#
# The data is very different compared to the rest of the csvs. So we'll rename and drop columns to match the others.

# %%
df_week8 = pd.read_csv('datasets/2016/Week 8 Feedback (2016, incomplete) - results.csv')
df_week8.head()
# Out:
#                                   #  \
# 0  00b836bda84e6bdbe780af97e249e59f
# 1  39dde6dc0e1e375845d756fc7e39fc5f
# 2  5e56b9de91670b308cb98dd2848b8739
# 3  641081d05785b47a0f17448625da0d49
# 4  c29bdd4f5678d78b450f4494e0f53c8c
#
#    How likely is it that you would recommend the Make School Summer Academy to a friend?  \
# 0                                                 10
# 1                                                 10
# 2                                                 10
# 3                                                  9
# 4                                                  3
#
#         location                track Start Date (UTC) Submit Date (UTC)  \
# 0       New York           summerApps      9/7/16 1:03       9/7/16 1:04
# 1  San Francisco          summerIntro      9/7/16 1:03       9/7/16 1:04
# 2       New York          summerIntro      9/7/16 1:03       9/7/16 1:05
# 3      Sunnyvale  summerApps (4-week)      9/7/16 1:04       9/7/16 1:06
# 4  San Francisco          summerIntro      9/7/16 1:04       9/7/16 1:11
#
#    Network ID
# 0  3212b7a834
# 1  f4954355aa
# 2  3d69ca289b
# 3  261608f95d
# 4  d6672ddf6f

# %%
# Only select the columns that match other datasets.
df_week8 = df_week8.iloc[:, [1, 2, 3]]
# Rename columns.
df_week8.rename(columns={
    "How likely is it that you would recommend the Make School Summer Academy to a friend?": "Rating",
    "location": "Location",
    "track": "Track"
}, inplace=True)
df_week8["Week"] = 8

# %%
df_week8.head()
# Out:
#    Rating       Location                Track  Week
# 0      10       New York           summerApps     8
# 1      10  San Francisco          summerIntro     8
# 2      10       New York          summerIntro     8
# 3       9      Sunnyvale  summerApps (4-week)     8
# 4       3  San Francisco          summerIntro     8

# %% [markdown]
# Before I can add this dataframe to the 2016 dataframe I need to convert the rating column to integers

# %%
df_week8['Rating'] = pd.to_numeric(df_week8.Rating)
df_week8.Rating.describe()
# Out:
# count    65.000000
# mean      8.646154
# std       1.735932
# min       3.000000
# 25%       8.000000
# 50%       9.000000
# 75%      10.000000
# max      10.000000
# Name: Rating, dtype: float64

# %%
df_2016.append(df_week8, sort=False, ignore_index=True)
df_2016["Year"] = "2016"
df_2016.head()
# Out:
#   Location Pacing Rating Track Week  Year
# 0   Taipei    3.0      3          7  2016
# 1   Taipei    3.0      4          7  2016
# 2   Taipei    3.0      4          7  2016
# 3   Taipei    4.0      4          7  2016
# 4   Taipei    4.0      5          7  2016

# %% [markdown]
# Cleaned!!

# %% [markdown]
# # Clean 2017 Data

# %% [markdown]
# There's not much that needs to be done for the 2017 dataset as it's all neatly packed into one csv.

# %%
df_2017 = pd.read_csv('datasets/2017/Student Feedback Surveys-Superview.csv')
# Tidy columns by removing 'ID' and renaming 'Rating (Num)'.
df_2017 = df_2017.drop(columns=['ID']).rename(columns={"Rating (Num)": "Rating", "Schedule Pacing": "Pacing"})
# Drop any NA/null data
df_2017 = df_2017.dropna()
# Make 'Rating' column numerical.
df_2017['Rating'] = pd.to_numeric(df_2017.Rating)
df_2017.head()
# Out:
#         Location           Track    Week  Rating             Pacing
# 0  San Francisco  Apps, Explorer  Week 1       3         Just right
# 1    Los Angeles            Apps  Week 1       4  A little too fast
# 2  San Francisco           Games  Week 1       4       Way too slow
# 4  New York City  Apps, Explorer  Week 1       4         Just right
# 5   Redwood City            Apps  Week 1       5         Just right

# %% [markdown]
# The pacing and week are string values, but I want them to be integers to make it easier to calculate stuff.

# %%
def pace_to_int(pace):
    if pace == "Way too slow":
        return 1
    elif pace == "A little too slow":
        return 2
    elif pace == "Just right":
        return 3
    elif pace == "A little too fast":
        return 4
    elif pace == "Way too fast":
        return 5

def week_to_int(week):
    return int(week[-1])

df_2017["Pacing"] = df_2017.Pacing.apply(pace_to_int)
# 2018          Tokyo    1      8      4             Apps  2017
# 2019          Tokyo    1     10      3             Apps  2017
# 2020          Tokyo    1     10      3             Apps  2017
# 2021          Tokyo    1      7      4             Apps  2017
# 2022          Tokyo    1     10      3             Apps  2017
# 2023          Tokyo    1     10      3             Apps  2017
# 2024          Tokyo    1      8      3             Apps  2017
# 2025  New York City    4      5      4   Apps, Explorer  2017
# 2026  New York City    4     10      3             Apps  2017
# 2027  New York City    4      8      3             Apps  2017
# 2028  New York City    4      8      3   Apps, Explorer  2017
# 2029  New York City    4      5      3             Apps  2017
# 2030  New York City    4      8      3   Apps, Explorer  2017
# 2031  New York City    4      9      3            Games  2017
# 2032  New York City    4      8      4   Apps, Explorer  2017
# 2033  New York City    4     10      3   Apps, Explorer  2017
# 2034  New York City    4      9      3             Apps  2017
# 2035  New York City    4      6      4             Apps  2017
# 2036        Chicago    6      9      4   Apps, Explorer  2017
# 2037  New York City    4      9      3             Apps  2017
# 2038  New York City    4     10      3             Apps  2017
# 2039        Chicago    6     10      4             Apps  2017
# 2040        Chicago    6      9      3             Apps  2017
# 2041    Santa Clara    6     10      3             Apps  2017
# 2042    Santa Clara    6      8      3  Games, Explorer  2017
# 2043    Santa Clara    6     10      3   Apps, Explorer  2017
# 2044        Oakland    6     10      3   Apps, Explorer  2017
# 2045        Oakland    6      9      3             Apps  2017
# 2046    Santa Clara    6     10      4  Games, Explorer  2017
# 2047        Oakland    6      9      3             Apps  2017
# 2048  San Francisco    6      3      3             Apps  2017
# 2049    Santa Clara    6      9      3             Apps  2017
# 2050    Santa Clara    6      8      3             Apps  2017
# 2051    Santa Clara    6     10      3             Apps  2017
# 2052          Tokyo    1     10      4             Apps  2017
# 2053  New York City    4      6      3             Apps  2017
# 2054  New York City    4      9      3            Games  2017
# 2055    Santa Clara    6      8      3             Apps  2017
# 2056    Santa Clara    6      8      3   Apps, Explorer  2017
# 2057  San Francisco    6      9      3   Apps, Explorer  2017
# 2058          Tokyo    2     10      3             Apps  2017
# 2059          Tokyo    2      7      4             Apps  2017
# 2060          Tokyo    2      8      4             Apps  2017
# 2061          Tokyo    2      6      3             Apps  2017
# 2062          Tokyo    2      9      3             Apps  2017
# 2063          Tokyo    2     10      3             Apps  2017
# 2064          Tokyo    2      7      3             Apps  2017
# 2065          Tokyo    2     10      3             Apps  2017
# 2066          Tokyo    2      9      4             Apps  2017
# 2067          Tokyo    2      3      4             Apps  2017
# 2068          Tokyo    2      6      4             Apps  2017
# 2069          Tokyo    2      9      3             Apps  2017
# 2070          Tokyo    2     10      3             Apps  2017
# 2071          Tokyo    2     10      3             Apps  2017
# 2072          Tokyo    2     10      2             Apps  2017
# 2073          Tokyo    2      8      4             Apps  2017
# 2074          Tokyo    2      7      4             Apps  2017
# 2075          Tokyo    2     10      3             Apps  2017
# 2076          Tokyo    2      7      3             Apps  2017
# 2077          Tokyo    2      8      4             Apps  2017
# 2078          Tokyo    2      7      3             Apps  2017
# 2079          Tokyo    2      8      4             Apps  2017
# 2080          Tokyo    2     10      4             Apps  2017
# 2274  New York City    6     10      3  Games, Explorer  2017
# 2275  New York City    6      8      3             Apps  2017
# 2276  New York City    6      9      3             Apps  2017
# 2277    Los Angeles    8      7      5            Games  2017
# 2278    Los Angeles    8      9      3             Apps  2017
# 2279    Los Angeles    8      9      3            Games  2017
# 2280    Los Angeles    8     10      3             Apps  2017
# 2281    Los Angeles    8      9      2            Games  2017
# 2282    Los Angeles    8     10      3             Apps  2017
# 2283          Tokyo    3      9      4             Apps  2017
# 2284          Tokyo    3     10      3             Apps  2017
# 2285          Tokyo    3     10      3             Apps  2017
# 2286  New York City    6      8      3   Apps, Explorer  2017
# 2287  New York City    6     10      3   Apps, Explorer  2017
# 2288  Washington DC    7      5      3   Apps, Explorer  2017
# 2289  New York City    6      8      3             Apps  2017
# 2290  New York City    6     10      3             Apps  2017
# 2291          Tokyo    3      9      3             Apps  2017
# 2292          Tokyo    3      9      4             Apps  2017
# 2293  New York City    6     10      3             Apps  2017
# 2294    Los Angeles    8     10      4             Apps  2017
# 2295          Tokyo    3     10      3             Apps  2017
# 2296          Tokyo    3      8      3             Apps  2017
# 2297    Los Angeles    8      8      2            Games  2017
# 2298          Tokyo    3      8      3             Apps  2017
# 2299  New York City    7     10      3            Games  2017
# 2300  New York City    7     10      3  Games, Explorer  2017
# 2301  New York City    7     10      4            Games  2017
# 2302  New York City    7     10      3            Games  2017
# 2303  New York City    7      8      3             Apps  2017
# 2304  New York City    7      9      3            Games  2017
# 2305  New York City    7     10      3  Games, Explorer  2017
# 2306  New York City    7      9      3            Games  2017
# 2307  New York City    7      9      3             Apps  2017
# 2308  New York City    7      8      4             Apps  2017
# 2309  New York City    7     10      3            Games  2017
# 2310  New York City    7     10      3             Apps  2017
# 2311  New York City    7      9      3            Games  2017
# 2312  New York City    7      9      3             Apps  2017
# 2313  New York City    7     10      3             Apps  2017
# 2314  New York City    7      8      3             Apps  2017
# 2315  New York City    7      7      4             Apps  2017
# 2316  New York City    7      7      5   Apps, Explorer  2017
# 2317  New York City    7      7      3             Apps  2017
# 2318  New York City    7      9      3             Apps  2017
# 2319  New York City    7      8      3             Apps  2017
# 2320  New York City    7      7      3  Games, Explorer  2017
# 2321  New York City    7     10      3   Apps, Explorer  2017
# 2322  New York City    7     10      3   Apps, Explorer  2017
# 2323  New York City    7      9      4            Games  2017
# 2324  New York City    7      9      3             Apps  2017
# 2325  New York City    7      3      3             Apps  2017
# 2326  New York City    7     10      3  Games, Explorer  2017
# 2327  New York City    7     10      3   Apps, Explorer  2017
# 2328  New York City    7      8      3   Apps, Explorer  2017
# 2329  New York City    7     10      3             Apps  2017
# 2330  New York City    7      1      2   Apps, Explorer  2017
# 2331  New York City    5      8      3             Apps  2017
#
# [2332 rows x 6 columns]

# %% [markdown]
# # On To The Questions

# %% [markdown]
# With the data combined, we can now do some calculations.

# %% [markdown]
# - Which track had the most promoters/detractors?
# - What year had the greater NPS score?
# - What is the probability that someone who complains about schedule pacing (too fast/too slow) was a detractor?

# %% [markdown]
# ## Which track had the most promoters/detractors?

# %% [markdown]
# First, let's check the total number of each.
#
# We'll do this by selecting the

# %%
track_df = df.iloc[:, [2, 4]]
# Remove rows where there is no track.
track_df = track_df[track_df.Track != '']
track_df.head()
# Out:
#    Rating  Track
# 36      3  Intro
# 37      5  Intro
# 38      4  Games
# 39      4  Intro
# 40      4  Games

# %% [markdown]
# Some of the values under "Rating" appear as objects. We'll fix this first before we do any calculations.

# %%
for el in track_df["Rating"]:
    if type(el) is str:
        el = int(el)

# %%
ratings_list = list(track_df["Rating"])

# %%
for index, el in enumerate(ratings_list):
    ratings_list[index] = int(ratings_list[index])

# %%
track_df["Rating"] = ratings_list

# %%
def rating_to_type(rating):
    rating = int(rating)
    if rating < 6:
        return "Detractor"
    elif (rating >= 6) & (rating < 9):
        return "Passive"
    elif rating >= 9:
        return "Promoter"

track_df["Rating"] = df.Rating.apply(rating_to_type)
track_df.Rating.value_counts()
# Out:
# Detractor    865
# Promoter     739
# Passive      610
# Name: Rating, dtype: int64

# %% [markdown]
# So it seems there are quite a lot of detractors. Wonder which tracks are contributing to this high number.

# %%
sns.countplot(y="Track", hue="Rating", data=track_df)

# %% [markdown]
# From this chart we see that the Apps track has the most promoters total. However, it's also visible that it had the most participants in general (evident by the high number of each).
#
# This is making me think, perhaps an nps score for each track would be a better indicator of performance, though I still feel as though this isn't as reliable as I'd like it to be, due to the wide range in participants for each track.

# %% [markdown]
# ## NPS scores for each Track

# %% [markdown]
# First thing to do is create an empty data frame with the index and columns of interest.

# %%
tracks = track_df.Track.unique()
track_nps_df = pd.DataFrame(index=tracks, columns=["NPS"])
track_nps_df
# Out:
#                  NPS
# Intro            NaN
# Games            NaN
# Apps             NaN
# VR               NaN
# Apps, Explorer   NaN
# Games, Explorer  NaN

# %%
def calculate_nps(data):
    # Grab detractors and promoters.
    df_detractors = data[data["Rating"] == "Detractor"]
    df_promoters = data[data["Rating"] == "Promoter"]
    
    # Calculate and return nps score.
    nps_score = (df_promoters.Rating.count() - df_detractors.Rating.count()) / data.Rating.count()
    return nps_score

# %%
for track in tracks:
    nps_score = calculate_nps(track_df[track_df["Track"] == track])
    track_nps_df.loc[track].NPS = nps_score

# %%
track_nps_df.plot.bar()

# %% [markdown]
# That's odd, it looks like Apps has a very low score. Let's double check that.

# %%
track_nps_df.loc["Apps"]
# Out:
# NPS    0.00394945
# Name: Apps, dtype: object

# %% [markdown]
# Not bad! At least it's positive 👌🏾
#
# But now my question is, which year had the best scores?

# %% [markdown]
# # What year had the greater NPS score?

# %%
track_df["Rating"] = track_df.Rating.astype('category')

# %%
track_df.Rating.value_counts().plot(kind='bar')

# %% [markdown]
# So, it looks like for 2016 and 2017 combined, there were more detractors than promoters.
#
# Next, we'll check which track had the most promoters and detractors.

# %%
track_df["Track"] = track_df.Track.astype("category")

# %%
df_detractors = track_df[track_df["Rating"] == "Detractor"]
df_promoters = track_df[track_df["Rating"] == "Promoter"]

# %%
nps_score = (df_promoters.count() - df_detractors.count()) / track_df.count()
nps_score
# Out:
# Rating   -0.056911
# Track    -0.056911
# dtype: float64
